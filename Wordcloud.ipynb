# %% [markdown]
# # Wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
word_cloud = WordCloud()

# %%
palavras = ('DESENVOLVE_2022 Lógica Programação ALURA Primeiros_Passos Matplotlib GRUPO_BOTICÁRIO Javascript ALURA HTML Numpy GRUPO_BOTICÁRIO Business_Intelligence Pandas Regressão_Linear Lógica Programação Primeiros_Passos Javascript HTML Numpy Business_Intelligence Pandas GRUPO_BOTICÁRIO Regressão_Linear ALURA Prevendo Resultados Colab PYTHON Data_Science Primeiros_Passos Jupyter_Notebook PYTHON Data_Science Funções Pacotes PANDAS Anaconda PYTHON Data_Science Linguagem Numpy Lógica_de_Programação Python linguagem GRUPO_BOTICÁRIO Business_Inteligence PYTHON Avançando linguagem Matplotlib PYTHON Pandas Tratando DADOS Data_Science Primeiros_Passos DESENVOLVE_2022 Pycharm Sublime_Text JavaScript GRUPO_BOTICÁRIO Git GitHub LGPD HTML Built-in Functions PYTHON Tuplas Matplotlib Listas PYTHON ALURA PANDAS Matplotlib DESENVOLVE_2022 NUMPY')

# %%
type(palavras)
# Out:
# str

# %%
py_mask = np.array(Image.open("gato.jpg"))
word_cloud = WordCloud(background_color="white", max_words=2000,
               max_font_size=300, mask=py_mask,
               random_state=42, width=200, height=200)
word_cloud.generate(text=palavras)
fig, ax = plt.subplots(figsize=(50,30))      
plt.imshow(word_cloud, interpolation="bilinear")
plt.axis('off')
plt.show()

plt.imshow(word_cloud);
word_cloud.to_file("desenvolve.png")
